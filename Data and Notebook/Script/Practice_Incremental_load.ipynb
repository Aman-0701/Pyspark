-- %% [markdown]
-- #### Source

-- %%
SELECT * FROM sales_new.Orders

-- %%
-- CREATE DATABASE DWH_new

-- %% [markdown]
-- #### Staging Layer

-- %%
-- CREATE OR REPLACE TABLE DWH_new.stg_orders
-- AS
-- SELECT * FROM sales_new.Orders

-- %% [markdown]
-- #### Transformation Layer

-- %%
-- CREATE OR REPLACE TABLE DWH_new.trans_orders
-- AS 
-- SELECT * FROM DWH_new.stg_orders where Quantity is not null

-- %% [markdown]
-- #### Core Layer

-- %%
-- This is where we start building Dimension and Fact tables

-- %% [markdown]
-- #### Creating source table

-- %%
create table if not exists datamodelling.default.source_data
(
  order_id INT PRIMARY KEY,
  order_date Date,
  customer_id int,
  customer_name varchar(100),
  customer_email varchar(100),
  product_id int,
  product_name varchar(100),
  product_category varchar(50),
  quantity int,
  unit_price decimal(10,2),
  payment_type varchar(50),
  country varchar(50),
  last_updateed date
)

-- %%
-- Initial load 
INSERT INTO datamodelling.default.source_data VALUES 
(1001, '2024-07-01', 1, 'Alice Johnson', 'alice@gmail.com', 501, 'iPhone 14', 'Electronics', 1, 999.99, 'Credit Card', 'USA', '2024-07-01'),
(1002, '2024-07-01', 2, 'Bob Smith', 'bob@yahoo.com', 502, 'AirPods Pro', 'Electronics', 2, 199.99, 'PayPal', 'USA', '2024-07-01'),
(1003, '2024-07-01', 3, 'Charlie Brown', 'charlie@outlook.com', 503, 'Nike Shoes', 'Footwear', 1, 129.99, 'Credit Card', 'Canada', '2024-07-01');

-- %%
select * from datamodelling.default.source_data

-- %%
-- Incremental load
insert into datamodelling.default.source_data values 
(1004, '2024-07-02', 4,'David Lee','Davic@abc.com',504,'Samsung S23','Electronics',1,899.9,'Credit Card','USA','2024-07-02'),
(1005,'2024-07-02',1,'Alice Johnson','alice@gmail.com',503,'Nie Shoes','Footwear',2,129.99,'Credit Card','USA','2024-07-02')

# %%
if spark.catalog.tableExists('datamodelling.bronze.bronze_table'):
    last_load_date = spark.sql("""select max(order_date) from datamodelling.bronze.bronze_table""").collect()[0][0]
else:
    last_load_date = '1900-01-01'

# %%
last_load_date

# %%
spark.sql(f"""select * from datamodelling.default.source_data 
where order_date > '{last_load_date}'""").createOrReplaceTempView('bronze_source')

# %%
# %sql
create or replace table datamodelling.bronze.bronze_table
as
select * from bronze_source

# %%
# %sql
select * from datamodelling.bronze.bronze_table
